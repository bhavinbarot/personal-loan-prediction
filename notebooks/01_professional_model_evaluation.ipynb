# %% [markdown]
# # Professional Model Evaluation
#
# This notebook is the corrected portfolio workflow. It preserves the original course notebooks and runs the reproducible evaluation code in `src/loan_modeling`.
#
# The final holdout test set is touched only after model selection and threshold selection are complete.

# %% [markdown]
# ## Evaluation Architecture
#
# Raw data -> stratified 80/20 holdout split -> 5-fold stratified CV on training data -> model selection by average precision -> top-10% campaign threshold from out-of-fold training probabilities -> one final holdout evaluation.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))
PROJECT_ROOT

# %%
from loan_modeling.evaluate import main

main()

# %% [markdown]
# ## Outputs
#
# The run writes model-selection, holdout, campaign, and confusion-matrix tables to `reports/tables/`, plus a machine-readable run summary at `reports/run_summary.json`.
